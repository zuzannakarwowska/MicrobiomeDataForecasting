# %% [markdown]
# ASSIGN TAXONOMY TO THE FEATURE TABLE
#
# 1. Read feature table, metadata and representative seuqences.
# 2. Filter gut samples relates sequences from the representative seuqences artifact.
# 3. Asign taxonomy to seuqences.
# 4. Collapse taxonomy to chosen level.

# %%
import pandas as pd
from qiime2 import Artifact
from qiime2 import Metadata

from qiime2.plugins.feature_classifier.methods import classify_sklearn
from qiime2.plugins import feature_classifier
from qiime2.plugins.feature_table.methods import filter_seqs, filter_samples
from qiime2.plugins.taxa.methods import collapse

# %% [markdown]
# ### read feature table

# %%
ftable_file = '/storage/zkarwowska/microbiome-interactions/datasets/processed/qiita_550/raw_data/57456_reference-hit.biom'
ftable = Artifact.import_data('FeatureTable[Frequency]', ftable_file)

# %% [markdown]
# ### read metadata

# %%
metadata_file = '/storage/zkarwowska/microbiome-interactions/datasets/processed/qiita_550/raw_data/550_metadata.txt'
metadata = Metadata.load(metadata_file)

# %% [markdown]
# ### read representative sequences

# %%
seq_file = '/storage/zkarwowska/microbiome-interactions/datasets/processed/qiita_550/raw_data/rep_seqs.qza'
res_seqs = Artifact.load(seq_file)

# %% [markdown]
# ### filter representative sequences

# %%
filtered_ftable = filter_samples(table=ftable,
                                 metadata = metadata,
                                 where="[sample_type]='feces'")

filtered_ftable = filter_samples(table=filtered_ftable.filtered_table,
                                 metadata = metadata,
                                 where="[mislabeled]='FALSE'")
           
filtered_seqs = filter_seqs(data = res_seqs, 
                            table = filtered_ftable.filtered_table)

# %% [markdown]
# ### assign taxonomy

# %%
classifier_path = '/storage/zkarwowska/classfier/'
gg_classifier = Artifact.import_data('TaxonomicClassifier', classifier_path)

# %%
taxonomy = feature_classifier.methods.classify_sklearn(reads = filtered_seqs.filtered_data,
                                                       classifier = gg_classifier)

# %% [markdown]
# ### collapse taxonomy on a chosen level

# %%
collapsed_taxonomy = collapse(table=filtered_ftable.filtered_table,
                              taxonomy = taxonomy.classification, 
                              level = 2)

# %%
collapsed_taxonomy_df = collapsed_taxonomy.collapsed_table.view(pd.DataFrame)
#collapsed_taxonomy_df.to_csv('/storage/zkarwowska/microbiome-interactions/datasets/processed/taxonomy/550_family.csv')

# %%
collapsed_taxonomy_df
# Out:
#                          k__Bacteria;p__Proteobacteria  \
# 550.L1S343.s.1.sequence                          384.0
# 550.L2S7.s.2.sequence                            312.0
# 550.L2S81.s.2.sequence                           342.0
# 550.L1S273.s.1.sequence                          443.0
# 550.L1S112.s.1.sequence                          600.0
# ...                                                ...
# 550.L1S10.s.1.sequence                          1696.0
# 550.L2S52.s.2.sequence                           239.0
# 550.L1S200.s.1.sequence                          128.0
# 550.L1S161.s.1.sequence                           73.0
# 550.L1S319.s.1.sequence                          341.0
#
#                          k__Bacteria;p__Fusobacteria  \
# 550.L1S343.s.1.sequence                          0.0
# 550.L2S7.s.2.sequence                            0.0
# 550.L2S81.s.2.sequence                           0.0
# 550.L1S273.s.1.sequence                          0.0
# 550.L1S112.s.1.sequence                          0.0
# ...                                              ...
# 550.L1S10.s.1.sequence                           0.0
# 550.L2S52.s.2.sequence                           0.0
# 550.L1S200.s.1.sequence                          0.0
# 550.L1S161.s.1.sequence                          0.0
# 550.L1S319.s.1.sequence                          0.0
#
#                          k__Bacteria;p__Firmicutes  \
# 550.L1S343.s.1.sequence                     9904.0
# 550.L2S7.s.2.sequence                      10198.0
# 550.L2S81.s.2.sequence                      9756.0
# 550.L1S273.s.1.sequence                     8809.0
# 550.L1S112.s.1.sequence                    10112.0
# ...                                            ...
# 550.L1S10.s.1.sequence                      4314.0
# 550.L2S52.s.2.sequence                      6891.0
# 550.L1S200.s.1.sequence                     9820.0
# 550.L1S161.s.1.sequence                     8089.0
# 550.L1S319.s.1.sequence                    11381.0
#
#                          k__Bacteria;p__Bacteroidetes  \
# 550.L1S343.s.1.sequence                       15558.0
# 550.L2S7.s.2.sequence                         20158.0
# 550.L2S81.s.2.sequence                        17441.0
# 550.L1S273.s.1.sequence                       22864.0
# 550.L1S112.s.1.sequence                       19751.0
# ...                                               ...
# 550.L1S10.s.1.sequence                        18604.0
# 550.L2S52.s.2.sequence                        14551.0
# 550.L1S200.s.1.sequence                       22487.0
# 550.L1S161.s.1.sequence                       18777.0
# 550.L1S319.s.1.sequence                       16042.0
#
#                          k__Bacteria;p__Actinobacteria  \
# 550.L1S343.s.1.sequence                            6.0
# 550.L2S7.s.2.sequence                              0.0
# 550.L2S81.s.2.sequence                             2.0
# 550.L1S273.s.1.sequence                            6.0
# 550.L1S112.s.1.sequence                            4.0
# ...                                                ...
# 550.L1S10.s.1.sequence                             0.0
# 550.L2S52.s.2.sequence                             0.0
# 550.L1S200.s.1.sequence                           15.0
# 550.L1S161.s.1.sequence                            0.0
# 550.L1S319.s.1.sequence                            2.0
#
#                          k__Bacteria;p__Tenericutes  \
# 550.L1S343.s.1.sequence                         2.0
# 550.L2S7.s.2.sequence                          61.0
# 550.L2S81.s.2.sequence                        181.0
# 550.L1S273.s.1.sequence                         0.0
# 550.L1S112.s.1.sequence                         0.0
# ...                                             ...
# 550.L1S10.s.1.sequence                          0.0
# 550.L2S52.s.2.sequence                         33.0
# 550.L1S200.s.1.sequence                         0.0
# 550.L1S161.s.1.sequence                         0.0
# 550.L1S319.s.1.sequence                         2.0
#
#                          k__Bacteria;p__Cyanobacteria  \
# 550.L1S343.s.1.sequence                           0.0
# 550.L2S7.s.2.sequence                             0.0
# 550.L2S81.s.2.sequence                            0.0
# 550.L1S273.s.1.sequence                           0.0
# 550.L1S112.s.1.sequence                           0.0
# ...                                               ...
# 550.L1S10.s.1.sequence                            0.0
# 550.L2S52.s.2.sequence                            0.0
# 550.L1S200.s.1.sequence                           0.0
# 550.L1S161.s.1.sequence                           0.0
# 550.L1S319.s.1.sequence                           0.0
#
#                          k__Bacteria;p__Verrucomicrobia  \
# 550.L1S343.s.1.sequence                             0.0
# 550.L2S7.s.2.sequence                              16.0
# 550.L2S81.s.2.sequence                             17.0
# 550.L1S273.s.1.sequence                             6.0
# 550.L1S112.s.1.sequence                            37.0
# ...                                                 ...
# 550.L1S10.s.1.sequence                            443.0
# 550.L2S52.s.2.sequence                              0.0
# 550.L1S200.s.1.sequence                             0.0
# 550.L1S161.s.1.sequence                            98.0
# 550.L1S319.s.1.sequence                             3.0
#
#                          k__Bacteria;p__Synergistetes  \
# 550.L1S343.s.1.sequence                           0.0
# 550.L2S7.s.2.sequence                             0.0
# 550.L2S81.s.2.sequence                            0.0
# 550.L1S273.s.1.sequence                           0.0
# 550.L1S112.s.1.sequence                           0.0
# ...                                               ...
# 550.L1S10.s.1.sequence                            0.0
# 550.L2S52.s.2.sequence                            0.0
# 550.L1S200.s.1.sequence                           0.0
# 550.L1S161.s.1.sequence                           0.0
# 550.L1S319.s.1.sequence                           0.0
#
#                          k__Archaea;p__Euryarchaeota  k__Bacteria;__  \
# 550.L1S343.s.1.sequence                          0.0             0.0
# 550.L2S7.s.2.sequence                            0.0             0.0
# 550.L2S81.s.2.sequence                           0.0             0.0
# 550.L1S273.s.1.sequence                          0.0             0.0
# 550.L1S112.s.1.sequence                          0.0             0.0
# ...                                              ...             ...
# 550.L1S10.s.1.sequence                           0.0             0.0
# 550.L2S52.s.2.sequence                           0.0             0.0
# 550.L1S200.s.1.sequence                          0.0             0.0
# 550.L1S161.s.1.sequence                          0.0             0.0
# 550.L1S319.s.1.sequence                          0.0             0.0
#
#                          k__Bacteria;p__Acidobacteria
# 550.L1S343.s.1.sequence                           0.0
# 550.L2S7.s.2.sequence                             0.0
# 550.L2S81.s.2.sequence                            0.0
# 550.L1S273.s.1.sequence                           0.0
# 550.L1S112.s.1.sequence                           0.0
# ...                                               ...
# 550.L1S10.s.1.sequence                            0.0
# 550.L2S52.s.2.sequence                            0.0
# 550.L1S200.s.1.sequence                           0.0
# 550.L1S161.s.1.sequence                           0.0
# 550.L1S319.s.1.sequence                           0.0
#
# [462 rows x 12 columns]
